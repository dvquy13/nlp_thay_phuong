# %%
import pandas as pd

# %%
def load_sent(raw_txt):
    return list(filter(lambda x: x != '\n', raw_txt))

def split_word(s):
    return [x for x in s.split() if x != " "]
assert split_word("\tThe/at jury/nn  presentments/nns Georgia's/np$ ") == [
    "The/at",
    "jury/nn",
    "presentments/nns",
    "Georgia's/np$"
]

def get_tag(s):
    return s[s.rfind("/")+1:]
assert get_tag("The/at") == ("at")
assert get_tag("county/nn-t1") == ("nn-t1")
assert get_tag("georgia's/np$") == ("np$")

# %%
with open("../assignment2/data/brown_dataset/tagged_train.txt") as f:
    raw = f.readlines()
raw = load_sent(raw)

# %%
raw[:5]
# Out:
# ["The/at Fulton/np-tl County/nn-tl Grand/jj-tl Jury/nn-tl said/vbd Friday/nr an/at investigation/nn of/in Atlanta's/np$ recent/jj primary/nn election/nn produced/vbd ``/`` no/at evidence/nn ''/'' that/cs any/dti irregularities/nns took/vbd place/nn ./.\n",
#  "The/at jury/nn further/rbr said/vbd in/in term-end/nn presentments/nns that/cs the/at City/nn-tl Executive/jj-tl Committee/nn-tl ,/, which/wdt had/hvd over-all/jj charge/nn of/in the/at election/nn ,/, ``/`` deserves/vbz the/at praise/nn and/cc thanks/nns of/in the/at City/nn-tl of/in-tl Atlanta/np-tl ''/'' for/in the/at manner/nn in/in which/wdt the/at election/nn was/bedz conducted/vbn ./.\n",
#  "The/at September-October/np term/nn jury/nn had/hvd been/ben charged/vbn by/in Fulton/np-tl Superior/jj-tl Court/nn-tl Judge/nn-tl Durwood/np Pye/np to/to investigate/vb reports/nns of/in possible/jj ``/`` irregularities/nns ''/'' in/in the/at hard-fought/jj primary/nn which/wdt was/bedz won/vbn by/in Mayor-nominate/nn-tl Ivan/np Allen/np Jr./np ./.\n",
#  "``/`` Only/rb a/at relative/jj handful/nn of/in such/jj reports/nns was/bedz received/vbn ''/'' ,/, the/at jury/nn said/vbd ,/, ``/`` considering/in the/at widespread/jj interest/nn in/in the/at election/nn ,/, the/at number/nn of/in voters/nns and/cc the/at size/nn of/in this/dt city/nn ''/'' ./.\n",
#  "The/at jury/nn said/vbd it/pps did/dod find/vb that/cs many/ap of/in Georgia's/np$ registration/nn and/cc election/nn laws/nns ``/`` are/ber outmoded/jj or/cc inadequate/jj and/cc often/rb ambiguous/jj ''/'' ./.\n"]

# %%
tmp = raw
foo = [map(get_tag, x) for x in map(split_word, tmp)]

# %%
from collections import Counter
counter = Counter()
for sent in foo:
    for word in sent:
        counter[word] += 1

# %%
"aldkfj/lkasdjfasdf/123"["aldkfj/lkasdjfasdf/123".rfind("/")+1:]
# Out:
# '123'

# %%
'lasdjf8bbb'[:'lasdjf8bbb'.find('8')]
# Out:
# 'lasdjf'

# %%
count_df = pd.DataFrame.from_dict(dict(counter), orient='index').reset_index().rename(columns={0: "count", "index": "tag"})
count_df.sort_values("count", ascending=False)
# Out:
#              tag   count
# 402           nn  137017
# 163           in  108848
# 394           at   87641
# 83            jj   57796
# 396          nns   50824
# 228            ,   50110
# 123            .   50038
# 106           cc   32760
# 413           np   30702
# 284           rb   30444
# 159           vb   28978
# 94           vbn   26496
# 266           cs   19583
# 90           vbd   19196
# 88           vbg   14984
# 323          pps   13912
# 350          pp$   13501
# 18            to   13194
# 189        nn-tl   13153
# 244           cd   12841
# 147           md   11220
# 142         ppss   10335
# 379          bez    9800
# 391           ap    8663
# 239          ppo    7974
# 36            dt    7908
# 51            ql    7749
# 444         bedz    7732
# 100          vbz    7114
# 133           ``    6652
# ..           ...     ...
# 195     vb+vb-nc       1
# 360      nps$-tl       1
# 196        ex-hl       1
# 347    np+hvz-nc       1
# 357   pps+bez-hl       1
# 214       fw-jjr       1
# 212       nn+hvz       1
# 300   wps+bez-tl       1
# 155    rb+bez-nc       1
# 154   wdt+ber+pp       1
# 389       wpo-nc       1
# 351       hvg-hl       1
# 99     fw-pp$-nc       1
# 249     fw-to+vb       1
# 398     jj-tl-nc       1
# 397  fw-nn-tl-nc       1
# 119       fw-dts       1
# 126        uh-hl       1
# 132   nns$-tl-hl       1
# 388       ex+hvz       1
# 337    dt+bez-nc       1
# 136       jjt-nc       1
# 233      nps$-hl       1
# 385        md-nc       1
# 384       jjr+cs       1
# 148  ppss+ber-tl       1
# 382         *-nc       1
# 232      dod*-tl       1
# 227      wdt+dod       1
# 224       ppl-tl       1
#
# [449 rows x 2 columns]

# %%
def distill_tag(s):
    s = s.replace("fw-", "")
    hyphen_pos = s.find("-")
    if hyphen_pos != -1:
        rm_hyphen = s[:hyphen_pos]
    else:
        rm_hyphen = s
    return rm_hyphen.split("+")
assert distill_tag("nn+md") == ["nn", "md"]

# %%
test = count_df.copy()
test['tag'] = test['tag'].apply(distill_tag)

# %%
test.head()
# Out:
#         tag  count
# 0      [nr]      3
# 1      [md]     29
# 2  [nn, md]      1
# 3     [wrb]     36
# 4     [pp$]     10

# %%
count_df
# Out:
#              tag  count
# 0       fw-nr-tl      3
# 1          md-hl     29
# 2          nn+md      1
# 3         wrb-hl     36
# 4         pp$-hl     10
# 5         vbz-nc      7
# 6         jjr-nc      5
# 7      fw-nps-tl      1
# 8           )-hl    186
# 9          be-tl      1
# 10         od-nc      1
# 11        vbg+to      4
# 12        nr$-tl     10
# 13    wrb+bez-tl      3
# 14             (   2203
# 15         uh-tl     16
# 16         cc-tl    302
# 17         vb-tl     95
# 18            to  13194
# 19      fw-rb-tl      3
# 20         hv-hl      3
# 21         rp-hl     15
# 22        jj$-tl      1
# 23       wdt+bez     23
# 24      fw-in+nn      4
# 25           cd$      5
# 26            do   1108
# 27    wdt+bez-hl      1
# 28        nns-tl   2194
# 29       wps+hvd      1
# ..           ...    ...
# 419        cd-nc      5
# 420  fw-in+np-tl      1
# 421        np-hl    551
# 422          nn$   1273
# 423     ppss+ber    156
# 424       bem-nc      2
# 425       nn$-hl     20
# 426      nns$-nc      2
# 427     ppss+bem    137
# 428   pps+bez-nc      3
# 429        od-hl      8
# 430       dts-hl      2
# 431      wps+bez     13
# 432       fw-pps      1
# 433        do-hl      4
# 434      fw-*-tl      2
# 435        ql-nc      2
# 436   fw-ppl+vbz      2
# 437          dod    813
# 438       pp$-tl     31
# 439          doz    446
# 440        ap-tl     19
# 441       pps+md     96
# 442    fw-nn$-tl      4
# 443        vb-hl    133
# 444         bedz   7732
# 445       wps-nc      3
# 446       fw-ppl      9
# 447   ppss+hv-tl      1
# 448       fw-ppo      3
#
# [449 rows x 2 columns]

# %%
import string
puncs = set(string.punctuation) - set(["$"])

# %%
unstack = test.set_index('count')['tag'].apply(pd.Series).stack().reset_index(level=-1, drop=True).reset_index().rename(columns={0: "tag"})
tag_count = unstack.groupby(['tag'])['count'].sum().sort_values(ascending=False).to_frame().reset_index()

# %%
tag_count['tag'] = tag_count['tag'].apply(lambda x: "".join(chr for chr in x if not chr in puncs))
tag_count = tag_count[(tag_count['tag'] != "")]
count_total = tag_count['count'].sum()
tag_count['portion'] = tag_count['count'] / count_total * 100
tag_count
# Out:
#       tag   count    portion
# 0      nn  152345  17.102389
# 1      in  111030  12.464329
# 2      at   88830   9.972137
# 3      jj   62421   7.007438
# 4     nns   53785   6.037953
# 7      np   35204   3.952033
# 8      cc   33229   3.730318
# 9      rb   30599   3.435072
# 10     vb   29312   3.290592
# 11    vbn   27277   3.062141
# 12     cs   19619   2.202447
# 13    vbd   19225   2.158216
# 14    vbg   15290   1.716469
# 15    pps   14393   1.615771
# 16     cd   14199   1.593993
# 17    pp$   13560   1.522258
# 18     to   13286   1.491498
# 19     md   11654   1.308289
# 20   ppss   11171   1.254067
# 21    bez   10410   1.168636
# 22     ap    8727   0.979701
# 23     dt    8041   0.902690
# 24    ppo    8040   0.902578
# 25     ql    7762   0.871369
# 26   bedz    7741   0.869012
# 27    vbz    7227   0.811310
# 30     be    5926   0.665258
# 31    wdt    5028   0.564448
# 32     rp    4532   0.508766
# 33    ber    4428   0.497091
# ..    ...     ...        ...
# 75    wp$     234   0.026269
# 76    hvg     233   0.026157
# 77    dod     220   0.024697
# 78    qlp     202   0.022677
# 79    hvn     195   0.021891
# 80    wql     180   0.020207
# 81    nil     157   0.017625
# 82   pp$$     118   0.013247
# 83    dtx      92   0.010328
# 84    rbt      91   0.010216
# 85    pn$      81   0.009093
# 86   bedz      80   0.008981
# 87    nr$      78   0.008756
# 88    bez      69   0.007746
# 89    doz      66   0.007409
# 90    hvd      53   0.005950
# 91   nps$      38   0.004266
# 92    ber      32   0.003592
# 93     hv      20   0.002245
# 94    nrs      15   0.001684
# 95    hvz      14   0.001572
# 96    bed      10   0.001123
# 97    rb$       8   0.000898
# 98     rn       7   0.000786
# 99    ap$       7   0.000786
# 100   dt$       6   0.000674
# 101   cd$       5   0.000561
# 102   bem       4   0.000449
# 103   jj$       1   0.000112
# 104    pp       1   0.000112
#
# [95 rows x 3 columns]

# %%
tag_count = tag_count.groupby(['tag']).sum().sort_values('count', ascending=False).reset_index()

# %%
tags = pd.read_csv("./data/tags.csv", header=None, names=['tag', 'explanation'])

# %%
tags['tag'] = tags['tag'].apply(lambda x: x.lower())

# %%
tags
# Out:
#      tag                                        explanation
# 0    abl                      pre-qualifier (quite, rather)
# 1    abn                         pre-quantifier (half, all)
# 2    abx                              pre-quantifier (both)
# 3     ap              post-determiner (many, several, next)
# 4     at                               article (a, the, no)
# 5     be                                                 be
# 6    bed                                               were
# 7   bedz                                                was
# 8    beg                                              being
# 9    bem                                                 am
# 10   ben                                               been
# 11   ber                                           are, art
# 12   bez                                                 is
# 13    cc                 coordinating conjunction (and, or)
# 14    cd               cardinal numeral (one, two, 2, etc.)
# 15    cs           subordinating conjunction (if, although)
# 16    do                                                 do
# 17   dod                                                did
# 18   doz                                               does
# 19    dt        singular determiner/quantifier (this, that)
# 20   dti  singular or plural determiner/quantifier (some...
# 21   dts                   plural determiner (these, those)
# 22   dtx             determiner/double conjunction (either)
# 23    ex                                  existential there
# 24    fw       foreign word (hyphenated before regular tag)
# 25    hv                                               have
# 26   hvd                                   had (past tense)
# 27   hvg                                             having
# 28   hvn                              had (past participle)
# 29    in                                        preposition
# ..   ...                                                ...
# 48   pp$              possessive personal pronoun (my, our)
# 49  pp$$   second (nominal) possessive pronoun (mine, ours)
# 50   ppl  singular reflexive/intensive personal pronoun ...
# 51  ppls  plural reflexive/intensive personal pronoun (o...
# 52   ppo     objective personal pronoun (me, him, it, them)
# 53   pps  3rd. singular nominative pronoun (he, she, it,...
# 54  ppss  other nominative personal pronoun (I, we, they...
# 55   prp                                   Personal pronoun
# 56  prp$                                 Possessive pronoun
# 57    ql                           qualifier (very, fairly)
# 58   qlp                    post-qualifier (enough, indeed)
# 59    rb                                             adverb
# 60   rbr                                 comparative adverb
# 61   rbt                                 superlative adverb
# 62    rn               nominal adverb (here, then, indoors)
# 63    rp                   adverb/particle (about, off, up)
# 64    to                               infinitive marker to
# 65    uh                          interjection, exclamation
# 66    vb                                    verb, base form
# 67   vbd                                   verb, past tense
# 68   vbg                    verb, present participle/gerund
# 69   vbn                              verb, past participle
# 70   vbp            verb, non 3rd person, singular, present
# 71   vbz                        verb, 3rd. singular present
# 72   wdt                       wh- determiner (what, which)
# 73   wp$                     possessive wh- pronoun (whose)
# 74   wpo          objective wh- pronoun (whom, which, that)
# 75   wps          nominative wh- pronoun (who, which, that)
# 76   wql                                wh- qualifier (how)
# 77   wrb                      wh- adverb (how, where, when)
#
# [78 rows x 2 columns]

# %%
final = pd.merge(tags, tag_count, how='outer', on='tag').sort_values("count", ascending=False)
final
# Out:
#      tag                                        explanation     count  \
# 36    nn                              singular or mass noun  152345.0
# 29    in                                        preposition  111030.0
# 4     at                               article (a, the, no)   88830.0
# 30    jj                                          adjective   62421.0
# 38   nns                                        plural noun   53785.0
# 40    np                 proper noun or part of name phrase   35204.0
# 13    cc                 coordinating conjunction (and, or)   33229.0
# 59    rb                                             adverb   30599.0
# 66    vb                                    verb, base form   29312.0
# 69   vbn                              verb, past participle   27277.0
# 15    cs           subordinating conjunction (if, although)   19619.0
# 67   vbd                                   verb, past tense   19225.0
# 68   vbg                    verb, present participle/gerund   15290.0
# 53   pps  3rd. singular nominative pronoun (he, she, it,...   14393.0
# 14    cd               cardinal numeral (one, two, 2, etc.)   14199.0
# 48   pp$              possessive personal pronoun (my, our)   13560.0
# 64    to                               infinitive marker to   13286.0
# 34    md                modal auxiliary (can, should, will)   12249.0
# 54  ppss  other nominative personal pronoun (I, we, they...   11171.0
# 12   bez                                                 is   10479.0
# 3     ap              post-determiner (many, several, next)    8727.0
# 19    dt        singular determiner/quantifier (this, that)    8041.0
# 52   ppo     objective personal pronoun (me, him, it, them)    8040.0
# 7   bedz                                                was    7821.0
# 57    ql                           qualifier (very, fairly)    7762.0
# 71   vbz                        verb, 3rd. singular present    7227.0
# 5     be                                                 be    5926.0
# 72   wdt                       wh- determiner (what, which)    5028.0
# 63    rp                   adverb/particle (about, off, up)    4532.0
# 11   ber                                           are, art    4460.0
# ..   ...                                                ...       ...
# 9    bem                                                 am     333.0
# 0    abl                      pre-qualifier (quite, rather)     322.0
# 51  ppls  plural reflexive/intensive personal pronoun (o...     322.0
# 39  nns$                             possessive plural noun     307.0
# 74   wpo          objective wh- pronoun (whom, which, that)     278.0
# 73   wp$                     possessive wh- pronoun (whose)     234.0
# 27   hvg                                             having     233.0
# 58   qlp                    post-qualifier (enough, indeed)     202.0
# 28   hvn                              had (past participle)     195.0
# 76   wql                                wh- qualifier (how)     180.0
# 79   nil                                                NaN     157.0
# 49  pp$$   second (nominal) possessive pronoun (mine, ours)     118.0
# 22   dtx             determiner/double conjunction (either)      92.0
# 61   rbt                                 superlative adverb      91.0
# 47   pn$                         possessive nominal pronoun      81.0
# 80   nr$                                                NaN      78.0
# 43  nps$                      possessive plural proper noun      38.0
# 81   nrs                                                NaN      15.0
# 82   rb$                                                NaN       8.0
# 62    rn               nominal adverb (here, then, indoors)       7.0
# 83   ap$                                                NaN       7.0
# 84   dt$                                                NaN       6.0
# 85   cd$                                                NaN       5.0
# 86   jj$                                                NaN       1.0
# 87    pp                                                NaN       1.0
# 24    fw       foreign word (hyphenated before regular tag)       NaN
# 35    nc          cited word (hyphenated after regular tag)       NaN
# 55   prp                                   Personal pronoun       NaN
# 56  prp$                                 Possessive pronoun       NaN
# 70   vbp            verb, non 3rd person, singular, present       NaN
#
#       portion
# 36  17.102389
# 29  12.464329
# 4    9.972137
# 30   7.007438
# 38   6.037953
# 40   3.952033
# 13   3.730318
# 59   3.435072
# 66   3.290592
# 69   3.062141
# 15   2.202447
# 67   2.158216
# 68   1.716469
# 53   1.615771
# 14   1.593993
# 48   1.522258
# 64   1.491498
# 34   1.375084
# 54   1.254067
# 12   1.176382
# 3    0.979701
# 19   0.902690
# 52   0.902578
# 7    0.877993
# 57   0.871369
# 71   0.811310
# 5    0.665258
# 72   0.564448
# 63   0.508766
# 11   0.500684
# ..        ...
# 9    0.037383
# 0    0.036148
# 51   0.036148
# 39   0.034464
# 74   0.031209
# 73   0.026269
# 27   0.026157
# 58   0.022677
# 28   0.021891
# 76   0.020207
# 79   0.017625
# 49   0.013247
# 22   0.010328
# 61   0.010216
# 47   0.009093
# 80   0.008756
# 43   0.004266
# 81   0.001684
# 82   0.000898
# 62   0.000786
# 83   0.000786
# 84   0.000674
# 85   0.000561
# 86   0.000112
# 87   0.000112
# 24        NaN
# 35        NaN
# 55        NaN
# 56        NaN
# 70        NaN
#
# [88 rows x 4 columns]

# %%
final[(final['explanation'].isnull()) | (final['count'].isnull())]
# Out:
#      tag                                   explanation   count   portion
# 78   hvz                                           NaN  2496.0  0.280203
# 79   nil                                           NaN   157.0  0.017625
# 80   nr$                                           NaN    78.0  0.008756
# 81   nrs                                           NaN    15.0  0.001684
# 82   rb$                                           NaN     8.0  0.000898
# 83   ap$                                           NaN     7.0  0.000786
# 84   dt$                                           NaN     6.0  0.000674
# 85   cd$                                           NaN     5.0  0.000561
# 86   jj$                                           NaN     1.0  0.000112
# 87    pp                                           NaN     1.0  0.000112
# 24    fw  foreign word (hyphenated before regular tag)     NaN       NaN
# 35    nc     cited word (hyphenated after regular tag)     NaN       NaN
# 55   prp                              Personal pronoun     NaN       NaN
# 56  prp$                            Possessive pronoun     NaN       NaN
# 70   vbp       verb, non 3rd person, singular, present     NaN       NaN

# %%
final[~(final['explanation'].isnull()) & ~(final['count'].isnull())]
# Out:
#      tag                                        explanation     count  \
# 36    nn                              singular or mass noun  152345.0
# 29    in                                        preposition  111030.0
# 4     at                               article (a, the, no)   88830.0
# 30    jj                                          adjective   62421.0
# 38   nns                                        plural noun   53785.0
# 40    np                 proper noun or part of name phrase   35204.0
# 13    cc                 coordinating conjunction (and, or)   33229.0
# 59    rb                                             adverb   30599.0
# 66    vb                                    verb, base form   29312.0
# 69   vbn                              verb, past participle   27277.0
# 15    cs           subordinating conjunction (if, although)   19619.0
# 67   vbd                                   verb, past tense   19225.0
# 68   vbg                    verb, present participle/gerund   15290.0
# 53   pps  3rd. singular nominative pronoun (he, she, it,...   14393.0
# 14    cd               cardinal numeral (one, two, 2, etc.)   14199.0
# 48   pp$              possessive personal pronoun (my, our)   13560.0
# 64    to                               infinitive marker to   13286.0
# 34    md                modal auxiliary (can, should, will)   12249.0
# 54  ppss  other nominative personal pronoun (I, we, they...   11171.0
# 12   bez                                                 is   10479.0
# 3     ap              post-determiner (many, several, next)    8727.0
# 19    dt        singular determiner/quantifier (this, that)    8041.0
# 52   ppo     objective personal pronoun (me, him, it, them)    8040.0
# 7   bedz                                                was    7821.0
# 57    ql                           qualifier (very, fairly)    7762.0
# 71   vbz                        verb, 3rd. singular present    7227.0
# 5     be                                                 be    5926.0
# 72   wdt                       wh- determiner (what, which)    5028.0
# 63    rp                   adverb/particle (about, off, up)    4532.0
# 11   ber                                           are, art    4460.0
# ..   ...                                                ...       ...
# 31   jjr                              comparative adjective    1828.0
# 44    nr                 adverbial noun (home, today, west)    1749.0
# 37   nn$                           possessive singular noun    1648.0
# 16    do                                                 do    1432.0
# 42   nps                                 plural proper noun    1258.0
# 17   dod                                                did    1037.0
# 60   rbr                                 comparative adverb     999.0
# 50   ppl  singular reflexive/intensive personal pronoun ...     972.0
# 33   jjt    morphologically superlative adjective (biggest)     927.0
# 2    abx                              pre-quantifier (both)     674.0
# 8    beg                                              being     620.0
# 18   doz                                               does     530.0
# 32   jjs    semantically superlative adjective (chief, top)     362.0
# 65    uh                          interjection, exclamation     360.0
# 9    bem                                                 am     333.0
# 0    abl                      pre-qualifier (quite, rather)     322.0
# 51  ppls  plural reflexive/intensive personal pronoun (o...     322.0
# 39  nns$                             possessive plural noun     307.0
# 74   wpo          objective wh- pronoun (whom, which, that)     278.0
# 73   wp$                     possessive wh- pronoun (whose)     234.0
# 27   hvg                                             having     233.0
# 58   qlp                    post-qualifier (enough, indeed)     202.0
# 28   hvn                              had (past participle)     195.0
# 76   wql                                wh- qualifier (how)     180.0
# 49  pp$$   second (nominal) possessive pronoun (mine, ours)     118.0
# 22   dtx             determiner/double conjunction (either)      92.0
# 61   rbt                                 superlative adverb      91.0
# 47   pn$                         possessive nominal pronoun      81.0
# 43  nps$                      possessive plural proper noun      38.0
# 62    rn               nominal adverb (here, then, indoors)       7.0
#
#       portion
# 36  17.102389
# 29  12.464329
# 4    9.972137
# 30   7.007438
# 38   6.037953
# 40   3.952033
# 13   3.730318
# 59   3.435072
# 66   3.290592
# 69   3.062141
# 15   2.202447
# 67   2.158216
# 68   1.716469
# 53   1.615771
# 14   1.593993
# 48   1.522258
# 64   1.491498
# 34   1.375084
# 54   1.254067
# 12   1.176382
# 3    0.979701
# 19   0.902690
# 52   0.902578
# 7    0.877993
# 57   0.871369
# 71   0.811310
# 5    0.665258
# 72   0.564448
# 63   0.508766
# 11   0.500684
# ..        ...
# 31   0.205213
# 44   0.196344
# 37   0.185006
# 16   0.160758
# 42   0.141224
# 17   0.116415
# 60   0.112149
# 50   0.109118
# 33   0.104066
# 2    0.075664
# 8    0.069602
# 18   0.059498
# 32   0.040638
# 65   0.040414
# 9    0.037383
# 0    0.036148
# 51   0.036148
# 39   0.034464
# 74   0.031209
# 73   0.026269
# 27   0.026157
# 58   0.022677
# 28   0.021891
# 76   0.020207
# 49   0.013247
# 22   0.010328
# 61   0.010216
# 47   0.009093
# 43   0.004266
# 62   0.000786
#
# [73 rows x 4 columns]
